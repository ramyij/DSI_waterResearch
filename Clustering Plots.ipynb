# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.vq import kmeans2, whiten
import pandas as pd

# %%
# leadCluster

# %%
# clustering dataset
# determine k using elbow method
 
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
import numpy as np

 
# create new plot and data
plt.plot()
X = arr
# leadCluster[['age of Distribution System','perc outlets over']].values
colors = ['b', 'g', 'r']
markers = ['o', 'v', 's']
 
# k means determine k
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
 
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('lead, econ, age of plumbing')
plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-a2257a6d784f> in <module>()
#      10 # create new plot and data
#      11 plt.plot()
# ---> 12 X = arr
#      13 # leadCluster[['age of Distribution System','perc outlets over']].values
#      14 colors = ['b', 'g', 'r']
#
# NameError: name 'arr' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.vq import kmeans2, whiten
import pandas as pd

leadCluster = pd.read_csv('lead_only.csv')
# leadCluster= leadCluster[['long','lat']]
y = np.array(leadCluster['perc outlets over'])
arr = leadCluster.values
gps = leadCluster[['long','lat']].values
# x, y = kmeans2(whiten(arr), 4, iter = 20) 

plt.scatter(gps[:,0], gps[:,1], c=y, cmap='viridis_r', alpha=0.33333);
plt.colorbar()
plt.title('NYC - Percent of outlets over threshold')
plt.xlim(-74.07,-73.7)
plt.ylim(40.56,41)
plt.show()
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-5-23ced62b9926> in <module>()
#       4 import pandas as pd
#       5
# ----> 6 leadCluster = pd.read_csv('lead_only.csv')
#       7 # leadCluster= leadCluster[['long','lat']]
#       8 y = np.array(leadCluster['perc outlets over'])
#
# ...

# %%
"""
Lead Data only (~4300 schools)
clustering on lat, long, scaled Lead Results
7 clusters
graphed on gps
"""

leadCluster = pd.read_csv('lead_only.csv')
# leadCluster= leadCluster[['long','lat']]

gps = leadCluster[['long','lat']].values
arr = leadCluster['perc outlets over'].values
print(len(leadCluster))

clusters = 2

x, y = kmeans2(whiten(arr), clusters, iter = 120) 
plt.scatter(gps[:,0], gps[:,1], c=y, alpha=0.33333);
# plt.xlim(-74.1,-73.7)
# plt.ylim(40.5,41)
plt.title("Clustered Lead Testing Results")
plt.legend()
plt.show()
# Out:
# 4317

# %%
a = np.array(['1','2','3'])
b = [0,1,1]

a[b]
# Out:
# array(['1', '2', '2'],
#       dtype='|S1')

# %%
"""
Sampled data (~1088 schools) 
clustering on age of plumbing and lead results
4 clusters
graphed on gps
"""

leadCluster = pd.read_csv('lead_plumbin_sample.csv')
# leadCluster= leadCluster[['long','lat']]
# leadCluster= leadCluster.values
gps = leadCluster[['long','lat']].values

arr = leadCluster[['age of Distribution System','perc outlets over']].values
print len(arr)
x, y = kmeans2(whiten(arr), 3, iter = 20)  
plt.scatter(gps[:,0], gps[:,1], c=y, alpha=0.33333);
# plt.xlim(-76.2,-76)
plt.ylim
plt.show()
# Out:
# 1088

# %%
arr[:,1]
# Out:
# array([ 0.        ,  0.        ,  0.1503268 , ...,  0.03      ,
#         0.16326531,  0.01714286])

# %%
"""
Sampled data (~850 schools) 
clustering on age of plumbing and lead results
3 clusters
graphed age of plumbing (x), and lead results(y)
"""

leadCluster = pd.read_csv('lead_plumbin_sample.csv')[['age of Distribution System','perc outlets over']]
arr = leadCluster.values
clusters = 2
print len(arr)
x, y = kmeans2(whiten(arr), clusters, iter = 20)  
plt.scatter(arr[:,0], arr[:,1], c=y, alpha=0.33333);
plt.title('Lead (y) and age of plumbing (x)')
plt.show()
# Out:
# 1088

# %%
"""
Sampled data (~800 schools) 
clustering on age of plumbing, lead results, economic status
graphed on gps
"""

leadCluster = pd.read_csv('lead_econ_plumbing_sample.csv')
# leadCluster= leadCluster[['long','lat']]
# leadCluster= leadCluster.values
gps = leadCluster[['long','lat']].values
clusters = 2

arr = leadCluster[['age of Distribution System','perc outlets over','math Econ Dis perc']].values
print len(arr)
x, y = kmeans2(whiten(arr), clusters, iter = 20)  
plt.scatter(arr[:,0], arr[:,1], c=y, alpha=0.33333);
plt.show()
# Out:
# 804

# %%
"""
Sampled data (~800 schools) 
clustering on age of plumbing, lead results, economic status
graphed on gps
"""

leadCluster = pd.read_csv('lead_econ_sample.csv')
# leadCluster= leadCluster[['long','lat']]
# leadCluster= leadCluster.values
gps = leadCluster[['long','lat']].values
clusters = 2

arr = leadCluster[['math Econ Dis perc','perc outlets over']].values
print len(arr)
x, y = kmeans2(whiten(arr), clusters, iter = 20)  
plt.scatter(arr[:,0], arr[:,1], c=y, alpha=0.33333);
plt.title('Lead (y) and Econ Status (x)')
plt.show()
# Out:
# 1917

# %%
allCor = leadCluster['perc outlets over'].corr(leadCluster['age of Distribution System'])
print 'All DataPoints'
print '    corr: ' + str(allCor)

leadCluster['cluster'] = y
for i in range(clusters):
    c = leadCluster[leadCluster['cluster'] == i]
    corr = c['perc outlets over'].corr(c['age of Distribution System'])
    center = x[i]
    print 'cluster ' + str(i) 
    print '   center: ' + str(center)
    print '   corr: ' + str(corr)
# Out:
# All DataPoints
#     corr: 0.059179485173
# cluster 0
#    center: [ 1.40967858  1.32468597  0.70855991]
#    corr: -0.0609605475961
# cluster 1
#    center: [ 1.15550121  0.50474924  2.30779666]
#    corr: 0.158471496337
